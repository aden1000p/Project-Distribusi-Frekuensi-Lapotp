# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# membuat distribusi frekuensi

array1 = np.array(
    [
        128,
        100,
        180,
        150,
        200,
        90,
        340,
        105,
        85,
        270,
        200,
        65,
        230,
        150,
        150,
        120,
        130,
        80,
        230,
        200,
        110,
        126,
        170,
        132,
        140,
        112,
        90,
        340,
        170,
        190,
    ]
)

jumlah_class = 7

frequency = 0
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 42
#      38 jumlah_class = 7
#      40 frequency = 0
# ---> 42 print(array1 > 65 and array1 < 104)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
min = np.min(array1)
max = np.max(array1)
range = max - min
classwidth = range / jumlah_class

# %%
data_frekuensi = {
    "ClassDepan": [
        65,
        int(65 + classwidth) + 1,
        int(105 + classwidth) + 1,
        int(145 + classwidth) + 1,
        int(185 + classwidth) + 1,
        int(225 + classwidth) + 1,
        int(265 + classwidth) + 1,
    ],
    "ClassBelakang": [
        int(65 + classwidth),
        int(105 + classwidth),
        int(145 + classwidth),
        int(185 + classwidth),
        int(225 + classwidth),
        int(265 + classwidth),
        int(304 + classwidth) + 1,
    ],
}


data = pd.DataFrame(data_frekuensi)
data
# Out:
#    ClassDepan  ClassBelakang
# 0          65            104
# 1         105            144
# 2         145            184
# 3         185            224
# 4         225            264
# 5         265            304
# 6         305            344
